# %%
import json
from kafka import KafkaProducer

producer = KafkaProducer(bootstrap_servers='ec2-3-80-52-188.compute-1.amazonaws.com:9092')

j = {
    "id":"happy_women",
    "face_nr": 3,
    "object_box": [278,25,150,150],
    "image_cut_out":"...",

}

producer.send('faces_found_detail', str.encode(json.dumps(j)))

# %%
# !pip install kafka-python
# Out:
# ...
#      |████████████████████████████████| 256kB 6.4MB/s
# ...
